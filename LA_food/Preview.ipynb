# %% [markdown]
# Food insecurity is a growing problem in Los Angeles due to the COVID-19 pandemic. Many residents have lost work or have seen their hours and income reduced since the start of the pandemic. According to a USC survey conducted between April and July of 2020, 25% of Los Angeles County households experienced food insecurity. Of those experiencing food insecurity, 82% are low income and 50% have children in the household.

# %% [markdown]
# The goal of this event is to help connect residents with on-the-ground resources and organizations that can help. This event will also provide an opportunity to deliver better information tools to nonprofits and policy leaders to help guide their decision-making around food policy. Below, you'll find available data sources to help achieve our goal!

# %%
import pandas as pd
import json
import plotly.express as px 
import folium
from folium import plugins

# %%
# if we want to see all columns, we set this parametr on
pd.set_option('display.max_columns', 999)

# %%
assistance = pd.read_csv("./data/Food_Assistance.csv")

# %%
assistance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   X             327 non-null    float64
#  1   Y             327 non-null    float64
#  2   OBJECTID      327 non-null    int64
#  3   source        324 non-null    object
#  4   ext_id        1 non-null      float64
#  5   cat1          327 non-null    object
#  6   cat2          327 non-null    object
#  7   cat3          0 non-null      float64
#  8   org_name      194 non-null    object
#  9   Name          327 non-null    object
#  10  addrln1       327 non-null    object
#  11  addrln2       23 non-null     object
#  12  city          327 non-null    object
#  13  state         327 non-null    object
#  14  hours         215 non-null    object
#  15  phones        323 non-null    object
#  16  email         0 non-null      float64
#  17  url           206 non-null    object
#  18  info1         0 non-null      float64
#  19  info2         0 non-null      float64
#  20  post_id       327 non-null    int64
#  21  description   323 non-null    object
#  22  zip           327 non-null    int64
#  23  link          327 non-null    object
#  24  use_type      327 non-null    object
#  25  latitude      327 non-null    float64
#  26  longitude     327 non-null    float64
#  27  date_updated  327 non-null    object
#  28  dis_status    0 non-null      float64
#  29  POINT_X       327 non-null    float64
#  30  POINT_Y       327 non-null    float64
# dtypes: float64(12), int64(3), object(16)
# memory usage: 79.3+ KB

# %%
assistance.head(3)
# Out:
#             X          Y  OBJECTID source  ext_id             cat1  \
# 0 -118.306022  33.883930       371    211     NaN  Social Services
# 1 -118.290245  33.743902       373    211     NaN  Social Services
# 2 -118.419329  34.263288       656    211     NaN  Social Services
#
#               cat2  cat3             org_name  \
# 0  Food Assistance   NaN                  NaN
# 1  Food Assistance   NaN                  NaN
# 2  Food Assistance   NaN  www.mendpoverty.org
#
#                                             Name                    addrln1  \
# 0  City Of Gardena Recreation And Human Services          1651 W. 162nd St.
# 1                   Toberman Neighborhood Center          131 N. Grand Ave.
# 2             Meet Each Need With Dignity - Mend  10641 N. San Fernando Rd.
#
#   addrln2       city state                                      hours  \
# 0     NaN    Gardena    CA                                        NaN
# 1     NaN  San Pedro    CA  Monday through Friday, 9:00am to 5:00pm.
# 2     NaN    Pacoima    CA                                        NaN
#
#                                               phones  email  \
# 0   Service/Intake and Administration (310) 217-9537    NaN
# 1  FAX (310) 832-6712,  Service/Intake and Admini...    NaN
# 2  FAX (818) 897-0128,  Service/Intake (818) 896-...    NaN
#
#                     url  info1  info2  post_id  \
# 0  www.ci.gardena.ca.us    NaN    NaN      776
# 1     www.toberman.org/    NaN    NaN      777
# 2   www.mendpoverty.org    NaN    NaN      902
#
#                                          description    zip  \
# 0  The agency provides advocacy, counseling servi...  90247
# 1  The agency provides advocacy, counseling servi...  90731
# 2  The agency provides education services, emerge...  91331
#
#                                    link use_type   latitude   longitude  \
# 0  http://egis3.lacounty.gov/lms/?p=776  publish  33.883930 -118.306022
# 1  http://egis3.lacounty.gov/lms/?p=777  publish  33.743902 -118.290245
# 2  http://egis3.lacounty.gov/lms/?p=902  publish  34.263288 -118.419329
#
#              date_updated  dis_status       POINT_X       POINT_Y
# 0  2017/10/30 11:50:59+00         NaN  6.468786e+06  1.780281e+06
# 1  2017/10/30 11:52:37+00         NaN  6.473428e+06  1.729307e+06
# 2  2017/10/16 14:44:00+00         NaN  6.434971e+06  1.918460e+06

# %%
assistance.cat2.unique()
# Out:
# array(['Food Assistance'], dtype=object)

# %%
assistance.cat1.unique()
# Out:
# array(['Social Services'], dtype=object)

# %%
pantries = pd.read_csv("./data/Food_Pantries_in_City_of_LA.csv")

# %%
pantries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Map Order     82 non-null     int64
#  1   Name          82 non-null     object
#  2   Number        82 non-null     object
#  3   Street        82 non-null     object
#  4   City          82 non-null     object
#  5   State         82 non-null     object
#  6   Zip           82 non-null     int64
#  7   Full Address  82 non-null     object
#  8   Phone Number  75 non-null     object
#  9   Type          82 non-null     object
#  10  Source        82 non-null     object
#  11  Latitude      82 non-null     float64
#  12  Longitude     82 non-null     float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 8.5+ KB

# %%
pantries.head(3)
# Out:
#    Map Order                                               Name Number  \
# 0          1  Catholic Charities of Los Angeles - St. Robert...    211
# 1          2  Los Angeles County Workforce Development, Agin...    133
# 2          3                           Bienestar Human Services   5326
#
#            Street         City State    Zip  \
# 0         3rd Ave  Los Angeles    CA  90291
# 1      N Sunol Dr  Los Angeles    CA  90063
# 2  E Beverly Blvd  Los Angeles    CA  90022
#
#                            Full Address    Phone Number         Type  \
# 0          211 3rd Ave, Los Angeles, CA  (310) 392-8701  Food Pantry
# 1       133 N Sunol Dr, Los Angeles, CA  (323) 260-2801  Food Pantry
# 2  5326 E Beverly Blvd, Los Angeles, CA  (323) 727-7896  Food Pantry
#
#                Source   Latitude   Longitude
# 0  Los Angeles County  33.996901 -118.476440
# 1  Los Angeles County  34.038686 -118.177998
# 2  Los Angeles County  34.029738 -118.149614

# %%
farmers_market = pd.read_csv("./data/Farmers_Markets_in_Los_Angeles.csv")

# %%
farmers_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  130 non-null    float64
#  1   Y                  130 non-null    float64
#  2   APPLICANT_SPONSER  130 non-null    object
#  3   MARKET_NAME        130 non-null    object
#  4   MARKET_MANAGER_    130 non-null    object
#  5   MARKET_LOCATION    130 non-null    object
#  6   MARKET_CITY        130 non-null    object
#  7   MARKET_ZIP         130 non-null    int64
#  8   WEEKDAY            130 non-null    object
#  9   SEASON             130 non-null    object
#  10  TIME               130 non-null    object
#  11  Email_             129 non-null    object
#  12  FID                130 non-null    int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 13.3+ KB

# %%
farmers_market.head(3)
# Out:
#             X          Y                  APPLICANT_SPONSER  \
# 0 -118.430574  34.048769        Rick Jose Hernandez Farmers
# 1 -118.292501  34.032575  Hunger Action Los Angeles (HALA)
# 2 -118.128139  34.093105                  City of Alhambra
#
#               MARKET_NAME       MARKET_MANAGER_       MARKET_LOCATION  \
# 0  Overland Community CFM  Rick Jose Hernandez      Pico/Overland Ave
# 1     Adams & Vermont CFM    Harry Brown/Hiegel  1432 West Adams Blvd
# 2            Alhambra CFM            Harry Wong       100 S Second St
#
#         MARKET_CITY  MARKET_ZIP     WEEKDAY      SEASON         TIME  \
# 0  West Los Angeles       90064     Sundays   Jul - Dec    8am - 2pm
# 1       Los Angeles       90018  Wednesdays  Year Round    2pm - 6pm
# 2          Alhambra       91801     Sundays  Year Round  830am - 1pm
#
#                                               Email_  FID
# 0                               airmachine01@aim.com    1
# 1  frank@hungeractionla.org; h.brownhiegel@ca.rr.com    2
# 2                           hwong@cityofalhambra.org    3

# %%
agriculture = pd.read_csv("./data/Agriculture_and_Food.csv")

# %%
agriculture.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   X             276 non-null    float64
#  1   Y             276 non-null    float64
#  2   OBJECTID      276 non-null    int64
#  3   source        276 non-null    object
#  4   ext_id        233 non-null    float64
#  5   cat1          276 non-null    object
#  6   cat2          276 non-null    object
#  7   cat3          276 non-null    object
#  8   org_name      276 non-null    object
#  9   Name          276 non-null    object
#  10  addrln1       269 non-null    object
#  11  addrln2       15 non-null     object
#  12  city          269 non-null    object
#  13  state         269 non-null    object
#  14  hours         0 non-null      float64
#  15  phones        265 non-null    object
#  16  url           0 non-null      float64
#  17  info1         0 non-null      float64
#  18  info2         36 non-null     float64
#  19  post_id       276 non-null    int64
#  20  description   0 non-null      float64
#  21  zip           269 non-null    float64
#  22  link          276 non-null    object
#  23  use_type      276 non-null    object
#  24  latitude      276 non-null    float64
#  25  longitude     276 non-null    float64
#  26  email         35 non-null     object
#  27  date_updated  276 non-null    object
#  28  dis_status    0 non-null      float64
#  29  POINT_X       276 non-null    float64
#  30  POINT_Y       276 non-null    float64
# dtypes: float64(14), int64(2), object(15)
# memory usage: 67.0+ KB

# %%
agriculture.head(3)
# Out:
#          X       Y  OBJECTID                                      source  \
# 0 -118.253  33.808      3654  HSIP Freedom AgriculturalMineralOperations
# 1 -118.419  33.916      3655  HSIP Freedom AgriculturalMineralOperations
# 2 -118.295  33.780      3656  HSIP Freedom AgriculturalMineralOperations
#
#    ext_id              cat1                  cat2  \
# 0     NaN  Private Industry  Agriculture and Food
# 1     NaN  Private Industry  Agriculture and Food
# 2     NaN  Private Industry  Agriculture and Food
#
#                                  cat3                    org_name  \
# 0  Agriculture and Mineral Operations  TechniGraphics & Inc (TGS)
# 1  Agriculture and Mineral Operations  TechniGraphics & Inc (TGS)
# 2  Agriculture and Mineral Operations  TechniGraphics & Inc (TGS)
#
#                    Name addrln1 addrln2 city state  hours phones  url  info1  \
# 0       Carson Refinery     NaN     NaN  NaN   NaN    NaN    NaN  NaN    NaN
# 1   El Segundo Refinery     NaN     NaN  NaN   NaN    NaN    NaN  NaN    NaN
# 2  Los Angeles Refinery     NaN     NaN  NaN   NaN    NaN    NaN  NaN    NaN
#
#    info2  post_id  description  zip                                   link  \
# 0    NaN     4460          NaN  NaN  http://egis3.lacounty.gov/lms/?p=4460
# 1    NaN     4461          NaN  NaN  http://egis3.lacounty.gov/lms/?p=4461
# 2    NaN     4462          NaN  NaN  http://egis3.lacounty.gov/lms/?p=4462
#
#   use_type  latitude  longitude email            date_updated  dis_status  \
# 0  publish    33.808   -118.253   NaN  2010/11/01 19:50:56+00         NaN
# 1  publish    33.916   -118.419   NaN  2010/11/01 19:50:56+00         NaN
# 2  publish    33.780   -118.295   NaN  2010/11/01 19:50:56+00         NaN
#
#         POINT_X       POINT_Y
# 0  6.484810e+06  1.752604e+06
# 1  6.434544e+06  1.792076e+06
# 2  6.472021e+06  1.742449e+06

# %%
assistance.index
# Out:
# RangeIndex(start=0, stop=327, step=1)

# %%
assistance.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'source', 'ext_id', 'cat1', 'cat2', 'cat3',
#        'org_name', 'Name', 'addrln1', 'addrln2', 'city', 'state', 'hours',
#        'phones', 'email', 'url', 'info1', 'info2', 'post_id', 'description',
#        'zip', 'link', 'use_type', 'latitude', 'longitude', 'date_updated',
#        'dis_status', 'POINT_X', 'POINT_Y'],
#       dtype='object')

# %%
a1 = assistance[['cat2','latitude','longitude', 'Name','addrln1']]
a1.columns = ['type','lat','long','name','info']

# %%
a1
# Out:
#                 type        lat        long  \
# 0    Food Assistance  33.883930 -118.306022
# 1    Food Assistance  33.743902 -118.290245
# 2    Food Assistance  34.263288 -118.419329
# 3    Food Assistance  34.095976 -117.871668
# 4    Food Assistance  34.087127 -117.964652
# ..               ...        ...         ...
# 322  Food Assistance  34.165034 -118.384812
# 323  Food Assistance  34.077543 -118.292419
# 324  Food Assistance  34.380017 -118.528529
# 325  Food Assistance  34.201255 -118.536630
# 326  Food Assistance  33.967905 -118.292002
#
#                                                   name  \
# 0        City Of Gardena Recreation And Human Services
# 1                         Toberman Neighborhood Center
# 2                   Meet Each Need With Dignity - Mend
# 3                American Asian Pacific Ministries Inc
# 4    City Of Baldwin Park Department Of Recreation ...
# ..                                                 ...
# 322     St. David's Episcopal Church - North Hollywood
# 323  City Of Los Angeles Economic and Workforce Dev...
# 324        New Life In His Presence - Valley Food Bank
# 325     House The - A Church Family - Valley Food Bank
# 326  Vermont Village Community Development Corporat...
#
#                           info
# 0            1651 W. 162nd St.
# 1            131 N. Grand Ave.
# 2    10641 N. San Fernando Rd.
# 3           19523 E Cypress St
# 4      4100 Baldwin Park Blvd.
# ..                         ...
# 322        11605 Magnolia Blvd
# 323           3910 Oakwood Ave
# 324              24346 Main St
# 325          18515 Sherman Way
# 326         7901 S Vermont Ave
#
# [327 rows x 5 columns]

# %%
all_ = pd.DataFrame(columns=['type','lat','long','name','info'])

# %%
all_ = pd.concat([all_, a1])

# %%
pantries.columns
# Out:
# Index(['Map Order', 'Name', 'Number', 'Street', 'City', 'State', 'Zip',
#        'Full Address', 'Phone Number', 'Type', 'Source', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
p1 = pantries[['Type','Latitude','Longitude', 'Name','Full Address']]
p1.columns = ['type','lat','long','name','info']

# %%
p1
# Out:
#            type        lat        long  \
# 0   Food Pantry  33.996901 -118.476440
# 1   Food Pantry  34.038686 -118.177998
# 2   Food Pantry  34.029738 -118.149614
# 3   Food Pantry  34.031566 -118.283933
# 4   Food Pantry  34.055414 -118.389307
# ..          ...        ...         ...
# 77  Food Pantry  34.034172 -118.269835
# 78  Food Pantry  34.039485 -118.223458
# 79  Food Pantry  33.997433 -118.291859
# 80  Food Pantry  33.957343 -118.235948
# 81  Food Pantry  33.924395 -118.251340
#
#                                                  name  \
# 0   Catholic Charities of Los Angeles - St. Robert...
# 1   Los Angeles County Workforce Development, Agin...
# 2                            Bienestar Human Services
# 3                      St. John's Episcopal Cathedral
# 4         Sova Food Pantry and Resource Center - West
# ..                                                ...
# 77                                 St. Francis Center
# 78  Latino Equality Alliance: Mi Centro: Pride Pantry
# 79  Boys & Girls Club of Metro Los Angeles: Challe...
# 80  Boys & Girls Club of Metro Los Angeles: Jordan...
# 81  Boys & Girls Club of Metro Los Angeles: Watts ...
#
#                                               info
# 0                     211 3rd Ave, Los Angeles, CA
# 1                  133 N Sunol Dr, Los Angeles, CA
# 2             5326 E Beverly Blvd, Los Angeles, CA
# 3                514 W Adams Blvd, Los Angeles, CA
# 4                8846 W Pico Blvd, Los Angeles, CA
# ..                                             ...
# 77          1835 S. Hope St. Los Angeles, CA 90015
# 78        553 S. Clarence St. Los Angeles CA 90033
# 79     5029 S. Vermont Ave., Los Angeles, CA 90037
# 80  2131 East Century Blvd., Los Angeles, CA 90002
# 81      1339 East 120th St., Los Angeles, CA 90059
#
# [82 rows x 5 columns]

# %%
all_ = pd.concat([all_, p1])

# %%
all_.shape
# Out:
# (409, 5)

# %%
farmers_market.columns
# Out:
# Index(['X', 'Y', 'APPLICANT_SPONSER', 'MARKET_NAME', 'MARKET_MANAGER_',
#        'MARKET_LOCATION', 'MARKET_CITY', 'MARKET_ZIP', 'WEEKDAY', 'SEASON',
#        'TIME', 'Email_', 'FID'],
#       dtype='object')

# %%
f1 = farmers_market[['Y','X', 'MARKET_NAME','MARKET_LOCATION']]
f1.columns = ['lat','long','name','info']

# %%
f1['type'] = 'Farmers market'
# Out:
# /Users/marigaldina/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
f1
# Out:
#            lat        long                    name                    info  \
# 0    34.048769 -118.430574  Overland Community CFM       Pico/Overland Ave
# 1    34.032575 -118.292501     Adams & Vermont CFM    1432 West Adams Blvd
# 2    34.093105 -118.128139            Alhambra CFM         100 S Second St
# 3    34.097953 -118.242828            Altadena CFM     1839 Blake Ave # 14
# 4    34.117640 -118.260162     Atwater Village CFM          3528 Larga Ave
# ..         ...         ...                     ...                     ...
# 125  33.959639 -118.413644   Westchester CFM - Wed     7000 Manchester Ave
# 126  34.062089 -118.446671    Westwood Village CFM        1030 Broxton Ave
# 127  33.979090 -118.033806     Whittier Uptown CFM  Bright/Philadelphia St
# 128  33.774413 -118.275859          Wilmington CFM      470 N Hawaiian Ave
# 129  34.106258 -118.342294     Hollywood Night CFM     1999 N Sycamore Ave
#
#                type
# 0    Farmers market
# 1    Farmers market
# 2    Farmers market
# 3    Farmers market
# 4    Farmers market
# ..              ...
# 125  Farmers market
# 126  Farmers market
# 127  Farmers market
# 128  Farmers market
# 129  Farmers market
#
# [130 rows x 5 columns]

# %%
all_ = pd.concat([all_, f1])

# %%
all_
# Out:
#                 type        lat        long  \
# 0    Food Assistance  33.883930 -118.306022
# 1    Food Assistance  33.743902 -118.290245
# 2    Food Assistance  34.263288 -118.419329
# 3    Food Assistance  34.095976 -117.871668
# 4    Food Assistance  34.087127 -117.964652
# ..               ...        ...         ...
# 125   Farmers market  33.959639 -118.413644
# 126   Farmers market  34.062089 -118.446671
# 127   Farmers market  33.979090 -118.033806
# 128   Farmers market  33.774413 -118.275859
# 129   Farmers market  34.106258 -118.342294
#
#                                                   name  \
# 0        City Of Gardena Recreation And Human Services
# 1                         Toberman Neighborhood Center
# 2                   Meet Each Need With Dignity - Mend
# 3                American Asian Pacific Ministries Inc
# 4    City Of Baldwin Park Department Of Recreation ...
# ..                                                 ...
# 125                              Westchester CFM - Wed
# 126                               Westwood Village CFM
# 127                                Whittier Uptown CFM
# 128                                     Wilmington CFM
# 129                                Hollywood Night CFM
#
#                           info
# 0            1651 W. 162nd St.
# 1            131 N. Grand Ave.
# 2    10641 N. San Fernando Rd.
# 3           19523 E Cypress St
# 4      4100 Baldwin Park Blvd.
# ..                         ...
# 125        7000 Manchester Ave
# 126           1030 Broxton Ave
# 127     Bright/Philadelphia St
# 128         470 N Hawaiian Ave
# 129        1999 N Sycamore Ave
#
# [539 rows x 5 columns]

# %%
agriculture.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'source', 'ext_id', 'cat1', 'cat2', 'cat3',
#        'org_name', 'Name', 'addrln1', 'addrln2', 'city', 'state', 'hours',
#        'phones', 'url', 'info1', 'info2', 'post_id', 'description', 'zip',
#        'link', 'use_type', 'latitude', 'longitude', 'email', 'date_updated',
#        'dis_status', 'POINT_X', 'POINT_Y'],
#       dtype='object')

# %%
ag1 = agriculture[['cat1','Y','X', 'Name','addrln1']]
ag1.columns = ['type','lat','long','name','info']

# %%
all_ = pd.concat([all_, ag1])

# %%
all_
# Out:
#                  type        lat        long  \
# 0     Food Assistance  33.883930 -118.306022
# 1     Food Assistance  33.743902 -118.290245
# 2     Food Assistance  34.263288 -118.419329
# 3     Food Assistance  34.095976 -117.871668
# 4     Food Assistance  34.087127 -117.964652
# ..                ...        ...         ...
# 271  Private Industry  34.006252 -118.216726
# 272  Private Industry  34.014919 -118.213124
# 273  Private Industry  33.998850 -118.176839
# 274  Private Industry  33.787939 -118.252177
# 275  Private Industry  33.776995 -118.251504
#
#                                                   name  \
# 0        City Of Gardena Recreation And Human Services
# 1                         Toberman Neighborhood Center
# 2                   Meet Each Need With Dignity - Mend
# 3                American Asian Pacific Ministries Inc
# 4    City Of Baldwin Park Department Of Recreation ...
# ..                                                 ...
# 271                            Americold Logistics Llc
# 272     Preferred Freezer Services Of Washington Blvd.
# 273                  Preferred Freezer Services Of Lbf
# 274           Preferred Freezer Services Of Wilmington
# 275                       E Street Cold Logistics, Llc
#
#                           info
# 0            1651 W. 162nd St.
# 1            131 N. Grand Ave.
# 2    10641 N. San Fernando Rd.
# 3           19523 E Cypress St
# 4      4100 Baldwin Park Blvd.
# ..                         ...
# 271       3163 East Vernon Ave
# 272    3200 E Washington Blvd.
# 273         4900 Bandini Blvd.
# 274             900 East M St.
# 275    "901 East ""E"" Street"
#
# [815 rows x 5 columns]

# %%
#initialize the map around LA County
laMap = folium.Map(location=[34.0522,-118.2437], zoom_start=9)

# %%
display(laMap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
with open('./data/cd_boundaries.geojson') as f:
    laArea = json.load(f)

# %%
#add the shape of LA County to the map
folium.GeoJson(laArea).add_to(laMap)

# %%
display(laMap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.RegularPolygonMarker(all_[all_['type']=='Farmert market'], popup = 'CU Boulder', fill_color = '#00ff40',
                            number_of_sides = 3, radius = 10).add_to(polygon_map)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-15e4dde69852> in <module>
#       1 folium.RegularPolygonMarker(all_[all_['type']=='Farmert market'], popup = 'CU Boulder', fill_color = '#00ff40',
# ----> 2                             number_of_sides = 3, radius = 10).add_to(polygon_map)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/folium/features.py in __init__(self, location, number_of_sides, rotation, radius, popup, tooltip, **kwargs)
#      74         super(RegularPolygonMarker, self).__init__(
#      75             location,
# ---> 76             popup=popup, tooltip=tooltip
#      77         )
#      78         self._name = 'RegularPolygonMarker'
#
# ~/opt/anaconda3/lib/python3.7/site-packages/folium/map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     275         super(Marker, self).__init__()
#     276         self._name = 'Marker'
# --> 277         self.location = validate_location(location)
#     278         self.options = parse_options(
#     279             draggable=draggable or None,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/folium/utilities.py in validate_location(location)
#      41     if isinstance(location, np.ndarray) \
#      42             or (pd is not None and isinstance(location, pd.DataFrame)):
# ---> 43         location = np.squeeze(location).tolist()
#      44     if not hasattr(location, '__len__'):
#      45         raise TypeError('Location should be a sized variable, '
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
all_[all_['type']=='Farmert market']

# %%
import plotly.graph_objects as go

# %%
all_.type.unique()

# %%
ALL = 'ALL'
def unique_sorted_values_plus_ALL(array):
    unique = array.unique().tolist()
    unique.sort()
    unique.insert(0, ALL)
    return unique

# %%
dropdown_type = widgets.Dropdown(options = unique_sorted_values_plus_ALL(all_.type))

# %%
dropdown_type

# %%
def dropdown_type_eventhandler(change):
    if (change.new == ALL):
        display(all_)
    else:
        display(all_[all_.type == change.new])

# %%
dropdown_type.observe(dropdown_type_eventhandler, names='value')

# %%
output_year = widgets.Output()

# %%
def dropdown_type_eventhandler(change):
    output_year.clear_output()
    with output_year:
        display(all_[all_.type == change.new])

# %%
display(output_year)
